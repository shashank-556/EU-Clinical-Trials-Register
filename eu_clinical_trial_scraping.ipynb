# %%
import re
from typing import List
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
eudract_no = '2013-000856-16'

# %%
base_url = f'https://www.clinicaltrialsregister.eu/ctr-search/trial/{eudract_no}/results'

# %%
raw_html = requests.get(base_url,verify = False)
# Out:
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.clinicaltrialsregister.eu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
soup = BeautifulSoup(raw_html.content,'lxml')

# %%
table_ids = ['trialInformationSection', 'subjectDispositionSection', 'baselineCharacteristicsSection',
             'endPointsSection', re.compile(r"^endPoint[0-9]+Section$"), 'adverseEventsSection', 'moreInformationSection']

# %% [markdown]
# ### Functions and Attributes

# %%
subject_dispo_dict = {
    'Allocation method':'blinding_type','Blinding Used':'blinding','Arm Title':'arms_number',
    'Arm Description':'arm_description','Arm Type':'arm_type','Investigational medicinal product name':
    'drug_name','Pharmaceutical forms':'dosage_form','Routes of administration':'route'
},

# %%
def get_arm_titles(table_id = table_ids[1],text = 'Arm title') :
    temp = soup.find('table',{'id':table_id})
    a = re.findall(text,temp.text)
    return len(a)
num_of_arm_titles = get_arm_titles()

# %%
def get_dataframe(df:pd.DataFrame = None) :
    if df is not None :
        df['arms'] = list(range(1,num_of_arm_titles+1))
    else :
        df = pd.DataFrame({'arms':list(range(1,num_of_arm_titles+1))})
    return df.set_index('arms')

# %%
def get_rows(table_id=None,temp=None,skip=3) -> List[BeautifulSoup]:
    if temp == None :
        temp = soup.find('table',{'id':table_id})
        
    rows = temp.find_all('tr')
    rows = rows[skip:]
    return rows

# %%
def get_first_two_columns_and_their_td(tr:BeautifulSoup) :
    tds = tr.find_all('td')
    if len(tds) < 2 :
        a = tds[0].text.strip()
        return a,None,tds[0],None,len(tds)
    a,b = tds[0],tds[1]
    a,b = a.text.strip(),b.text.strip()
    return a,b,tds[0],tds[1],len(tds)

# %%
def get_embedded_table(table_id=None,many=False,temp=None) :
    
    if temp == None :
        temp = soup.find('table',{'id':table_id})
    
    li = temp.find_all('td',{'class':'embeddedTableContainer'})
    ans = []
    #print(len(li))
    for i in range(len(li)) :
        df = pd.read_html(li[i].prettify(),flavor='bs4')[0]
        df = df.set_index(0).T

        if len(df.index)>num_of_arm_titles :
            df = df.drop(index=num_of_arm_titles+1)
        df = get_dataframe(df)
        ans.append(df)
    if many :
        return ans
    return ans[0]

# %%
def get_main_table(rows,break_text='') :
    drug=1
    flag = False
    df = get_dataframe()
    for i in rows :
        a,b,a_td,b_td,l_td = get_first_two_columns_and_their_td(i)
        if l_td>2 :
            break
        if a == '' :
            continue
        if b == '':
            continue

        if a == break_text :
            if flag :
                drug+=1
            else :
                flag = True
                
        if a not in df :
            df[a]= np.NaN
        df.loc[drug,a] = b
    return df

# %% [markdown]
# ## 0 - Trial Information Table

# %%
trial_info_dict = {'EudraCT number':'EudraCT number','Sponsor organisation name':'Sponser',
'Main objective of the trial':'objective','Date of interim/final analysis':'Study_start_date'
,'Global end of trial date':'Study_end_date','Worldwide total number of subjects':'Total Subject'}

# %%
indx = 0
trial_info_rows = get_rows(table_ids[indx])
final_trial_info = get_dataframe()

# %%
for i in range(len(trial_info_rows)) :
    a,b,a_td,b_td,l_td = get_first_two_columns_and_their_td(trial_info_rows[i])
    if a == '':
        continue
    if a == 'Additional study identifiers' :
        li = []
        i+=1
        while(i<len(trial_info_rows)) :
            
            a,b,a_td,b_td,l_td = get_first_two_columns_and_their_td(trial_info_rows[i])
            if 'header' in a_td.attrs['class'] :
                break
            li.append(b)
            i+=1
        final_trial_info['Additional study identifiers'] = ', '.join(li)
    if a == 'Population of trial subjects' :
        li,s = [],0
        i+=1
        while(i<len(trial_info_rows)) :
            
            a,b,a_td,b_td,l_td = get_first_two_columns_and_their_td(trial_info_rows[i])
            if 'header' in a_td.attrs['class'] or 'Worldwide' in a:
                break
            contr_pop = b.split(':')
            if len(contr_pop) == 2 :
                li.append(contr_pop[0].strip())
                s+= int(contr_pop[1].strip())
            i+=1
        final_trial_info['countries'] =  ', '.join(li)
        final_trial_info['Sites'] = s
        
    if a == 'Number of subjects enrolled per age group' :
        s,s_more_than65 = 0,0
        flag = False
        i+=1
        while(i<len(trial_info_rows)) :
            a,b,a_td,b_td,l_td = get_first_two_columns_and_their_td(trial_info_rows[i])
            s+= int(b)
            if a == 'From 65 to 84 years' :
                flag = True
            if flag :
                s_more_than65+=int(b)
            i+=1
            
        final_trial_info['Age'] = s
        final_trial_info['Age_more_than_65'] = s_more_than65
    if a in trial_info_dict :
        final_trial_info[trial_info_dict[a]] = b

# %%
final_trial_info
#final_trial_info.to_excel(f'{eudract_no}final_trial_info.xlsx')
# Out:
#          Additional study identifiers  \
# arms
# 1     -, NCT01854047, U1111-1138-3962
# 2     -, NCT01854047, U1111-1138-3962
# 3     -, NCT01854047, U1111-1138-3962
# 4     -, NCT01854047, U1111-1138-3962
# 5     -, NCT01854047, U1111-1138-3962
#
#                                        Sponser Study_start_date  \
# arms
# 1     Sanofi aventis recherche & développement      04 May 2015
# 2     Sanofi aventis recherche & développement      04 May 2015
# 3     Sanofi aventis recherche & développement      04 May 2015
# 4     Sanofi aventis recherche & développement      04 May 2015
# 5     Sanofi aventis recherche & développement      04 May 2015
#
#      Study_end_date                                          objective  \
# arms
# 1       08 Apr 2015  To evaluate the efficacy of different doses an...
# 2       08 Apr 2015  To evaluate the efficacy of different doses an...
# 3       08 Apr 2015  To evaluate the efficacy of different doses an...
# 4       08 Apr 2015  To evaluate the efficacy of different doses an...
# 5       08 Apr 2015  To evaluate the efficacy of different doses an...
#
#                                               countries  Sites Total Subject  \
# arms
# 1     South Africa, Spain, Turkey, Ukraine, United S...    776           776
# 2     South Africa, Spain, Turkey, Ukraine, United S...    776           776
# 3     South Africa, Spain, Turkey, Ukraine, United S...    776           776
# 4     South Africa, Spain, Turkey, Ukraine, United S...    776           776
# 5     South Africa, Spain, Turkey, Ukraine, United S...    776           776
#
#       Age  Age_more_than_65
# arms
# 1     776                74
# 2     776                74
# 3     776                74
# 4     776                74
# 5     776                74

# %% [markdown]
# ## 1-Subject Disposition Table

# %%
subject_dispo_dict = {
    'Allocation method':'blinding_type','Blinding used':'blinding','Arm title':'arms_number',
    'Arm description':'arm_description','Arm type':'arm_type','Investigational medicinal product name':
    'drug_name','Pharmaceutical forms':'dosage_form','Routes of administration':'route'
}

# %%
indx = 1
subject_dispo_rows = get_rows(table_ids[indx])
final_sub_dispo = get_dataframe()

# %%
drug = 1
flag = False
for i in subject_dispo_rows :
    a,b,a_td,b_td,l_td = get_first_two_columns_and_their_td(i)
    #print(a,b)
    if a in subject_dispo_dict :
        if subject_dispo_dict[a] not in final_sub_dispo:
            final_sub_dispo[subject_dispo_dict[a]] = np.NaN
        if a == 'Arm title' :
            if flag:
                drug+=1
            else :
                flag = True
        #print(a,b) 
        final_sub_dispo.loc[drug,subject_dispo_dict[a]] = b
        if subject_dispo_dict[a] == 'blinding_type' :
            if 'Randomised' in final_sub_dispo[subject_dispo_dict[a]][drug]:
                final_sub_dispo['randomization'] = 'Yes'
            else :
                final_sub_dispo['randomization'] = 'No'

# %%
final_sub_dispo.fillna(axis=0,method='ffill',inplace=True)
final_sub_dispo
# Out:
#                 blinding_type randomization      blinding  \
# arms
# 1     Randomised - controlled           Yes  Double blind
# 2     Randomised - controlled           Yes  Double blind
# 3     Randomised - controlled           Yes  Double blind
# 4     Randomised - controlled           Yes  Double blind
# 5     Randomised - controlled           Yes  Double blind
#
#                arms_number                                    arm_description  \
# arms
# 1              Placebo q2w  2 subcutaneous injections of Placebo (for Dupi...
# 2     Dupilumab 300 mg q2w  2 subcutaneous injections of Dupilumab 300 mg ...
# 3     Dupilumab 200 mg q2w  2 subcutaneous injections of Dupilumab 200 mg ...
# 4     Dupilumab 300 mg q4w  2 subcutaneous injections of Dupilumab 300 mg ...
# 5     Dupilumab 200 mg q4w  2 subcutaneous injections of Dupilumab 200 mg ...
#
#           arm_type                drug_name             dosage_form  \
# arms
# 1          Placebo  Placebo (for Dupilumab)  Solution for injection
# 2     Experimental                Dupilumab  Solution for injection
# 3     Experimental                Dupilumab  Solution for injection
# 4     Experimental  Placebo (for Dupilumab)  Solution for injection
# 5     Experimental  Placebo (for Dupilumab)  Solution for injection
#
#                  route
# arms
# 1     Subcutaneous use
# 2     Subcutaneous use
# 3     Subcutaneous use
# 4     Subcutaneous use
# 5     Subcutaneous use

# %%
#final_sub_dispo.to_excel(f'{eudract_no}final_sub_dispo.xlsx')

# %% [markdown]
# ## 2- Baseline Characterstics

# %%
indx = 2
baseline_char_rows = get_rows(table_ids[indx])
final_baseline_char = get_main_table(baseline_char_rows,'Reporting group title')

# %%
em = get_embedded_table(table_ids[indx])

# %%
final_baseline_char = pd.concat([final_baseline_char,em],axis=1)
final_baseline_char
# Out:
#      Reporting group title                        Reporting group description  \
# arms
# 1              Placebo q2w  2 subcutaneous injections of Placebo (for Dupi...
# 2     Dupilumab 300 mg q2w  2 subcutaneous injections of Dupilumab 300 mg ...
# 3     Dupilumab 200 mg q2w  2 subcutaneous injections of Dupilumab 200 mg ...
# 4     Dupilumab 300 mg q4w  2 subcutaneous injections of Dupilumab 300 mg ...
# 5     Dupilumab 200 mg q4w  2 subcutaneous injections of Dupilumab 200 mg ...
#
#      Reporting group values Number of subjects Age categorical  \
# arms
# 1               Placebo q2w                158             NaN
# 2      Dupilumab 300 mg q2w                157             NaN
# 3      Dupilumab 200 mg q2w                150             NaN
# 4      Dupilumab 300 mg q4w                157             NaN
# 5      Dupilumab 200 mg q4w                154             NaN
#
#      Units: Subjects Age continuous Units: years  \
# arms
# 1                NaN            NaN          NaN
# 2                NaN            NaN          NaN
# 3                NaN            NaN          NaN
# 4                NaN            NaN          NaN
# 5                NaN            NaN          NaN
#
#      arithmetic mean (standard deviation) Gender categorical Units: Subjects  \
# arms
# 1                               49 ± 12.7                NaN             NaN
# 2                             47.5 ± 12.4                NaN             NaN
# 3                               51 ± 13.4                NaN             NaN
# 4                             47.9 ± 13.1                NaN             NaN
# 5                             47.9 ± 13.1                NaN             NaN
#
#      Female Male Number of Subjects with Blood Eosinphil Count  \
# arms
# 1       104   54                                           NaN
# 2       103   54                                           NaN
# 3        96   54                                           NaN
# 4       100   57                                           NaN
# 5        87   67                                           NaN
#
#      Units: Subjects <0.3 Giga/L ≥ 0.3 Giga/L
# arms
# 1                NaN          90           68
# 2                NaN          93           64
# 3                NaN          85           65
# 4                NaN          91           66
# 5                NaN          92           62

# %%
arms_dict = final_baseline_char['Reporting group title'].to_dict()
arms_dict = {v:k for k,v in arms_dict.items()}
arms_dict
# Out:
# {'Placebo q2w': 1,
#  'Dupilumab 300 mg q2w': 2,
#  'Dupilumab 200 mg q2w': 3,
#  'Dupilumab 300 mg q4w': 4,
#  'Dupilumab 200 mg q4w': 5}

# %%
#final_baseline_char.to_excel(f'{eudract_no}final_baseline_char.xlsx')

# %% [markdown]
# ## 5- Adverse Events

# %%
ae_list = ['arms','type_of_ae','e_reference','endpoint','total_n','affected_n','occurence_n','occurence_related(sae)','deaths(sae)']

# %%
indx = 5
final_ae = pd.DataFrame()
for i in ae_list :
    final_ae[i] = np.NaN

# %%
ae_li = get_embedded_table(table_ids[indx],many=True)

# %%
def get_final_ae(type_of_ae,temp_df,cols) :
    i = 1
    while(i<len(cols)) :
        sr:pd.Series = temp_df.iloc[i]
        if sr.isnull().all() :
            if temp_df.iloc[i+1].isnull().all() :
                i+=1
                continue
            if i != 1 :
                #print(mat)
                for j in mat :
                    final_ae.loc[len(final_ae.index)] = j
            mat = np.array([[np.NaN]*len(ae_list)]*num_of_arm_titles,dtype=np.object0)
            mat[:,1] = type_of_ae
            mat[:,3] = sr.name 
            mat[:,0] = list(range(1,num_of_arm_titles+1))
        else :
            if sr.name == 'subjects affected / exposed' :
                mat[:,5] = pd.to_numeric(sr.str.split('/',1,expand=True)[0].str.strip(),errors='coerce')
                mat[:,4] = pd.to_numeric(sr.str.split('/',1,expand=True)[1].str.split('(',1,expand=True)[0].str.strip(),errors='coerce')
            if sr.name == 'occurrences all number' :
                mat[:,6] = pd.to_numeric(sr.str.strip(),errors='coerce')
            if sr.name == 'occurrences causally related to treatment / all' :
                mat[:,7] = sr.str.strip()
            if sr.name == 'deaths causally related to treatment / all' :
                mat[:,8] = sr.str.strip()
        i+=1

# %%
get_final_ae('sae',ae_li[0].T,ae_li[0].columns)
get_final_ae('nsae',ae_li[1].T,ae_li[1].columns)

# %%
ae_rows = get_rows(table_id=table_ids[5])
v = ''
for i in ae_rows :
    a,b,a_td,b_td,l_td = get_first_two_columns_and_their_td(i)
    if a == 'Dictionary name' :
        v = v+b
    elif a == 'Dictionary version' :
        v = v+b
        break
final_ae['e_reference'] = v

# %%
#final_ae.to_excel(f'{eudract_no}final_ae.xlsx')
final_ae
# Out:
#      arms type_of_ae e_reference  \
# 0     1.0        sae  MedDRA18.0
# 1     2.0        sae  MedDRA18.0
# 2     3.0        sae  MedDRA18.0
# 3     4.0        sae  MedDRA18.0
# 4     5.0        sae  MedDRA18.0
# ..    ...        ...         ...
# 295   1.0       nsae  MedDRA18.0
# 296   2.0       nsae  MedDRA18.0
# 297   3.0       nsae  MedDRA18.0
# 298   4.0       nsae  MedDRA18.0
# 299   5.0       nsae  MedDRA18.0
#
#                                               endpoint  total_n  affected_n  \
# 0    Total subjects affected by serious adverse events    158.0         9.0
# 1    Total subjects affected by serious adverse events    156.0        13.0
# 2    Total subjects affected by serious adverse events    148.0        10.0
# 3    Total subjects affected by serious adverse events    157.0        16.0
# 4    Total subjects affected by serious adverse events    150.0         6.0
# ..                                                 ...      ...         ...
# 295                                          Sinusitis    158.0        11.0
# 296                                          Sinusitis    156.0         6.0
# 297                                          Sinusitis    148.0         5.0
# 298                                          Sinusitis    157.0        13.0
# 299                                          Sinusitis    150.0        12.0
#
#      occurence_n occurence_related(sae) deaths(sae)
# 0            NaN                    NaN         NaN
# 1            NaN                    NaN         NaN
# 2            NaN                    NaN         NaN
# 3            NaN                    NaN         NaN
# 4            NaN                    NaN         NaN
# ..           ...                    ...         ...
# 295         14.0                    NaN         NaN
# 296          7.0                    NaN         NaN
# 297          7.0                    NaN         NaN
# 298         14.0                    NaN         NaN
# 299         14.0                    NaN         NaN
#
# [300 rows x 9 columns]

# %% [markdown]
# ## 4 -Endpoints

# %%
indx = 4
endpt_html = soup.find_all('table',{'id':table_ids[indx]})
final_endpoint = get_dataframe()
main_li: List[pd.DataFrame] = []
em_li = []
endpoint_dict = {'End point title':'endpoint_title','End point description':'endpoint_description','End point type':'ednpoint_type','End point timeframe':'endpoint_time',
'Number of subjects analysed':'n_analyzed','Units':'unit','Baseline':'baseline','Week':'values','Change from baseline':'cfb','Statistical analysis description':'statistical_analysis_description',
'Comparison groups':'comparison_groups','Analysis type':'analysis_type','P-value':'p_value','Method':'pvalue_method',
'Parameter type':'comparison_type','Point estimate':'comparison','level':'ci_level','sides':'sides','lower limit':'lower_limit','upper limit':'upper_limit'
}

# %%
for i in endpt_html :
    flag = False
    i_rows = get_rows(temp=i)
    main_li.append(get_main_table(i_rows))
    em_li.append(get_embedded_table(temp = i))
    main_li[-1].fillna(axis=0,method='ffill',inplace=True)
    for j in i_rows :
        a,b,a_td,b_td,l_td = get_first_two_columns_and_their_td(j)
        if a == 'Statistical analysis title' :
            flag = True
            drug = arms_dict[b.split('vs')[0].strip()]
            #print(a,drug)
        else :
            if flag :
                if l_td == 1 :
                    sdf,b = a.split(' ',1)
                    a = sdf.strip()
                    b = b.strip()
                if a not in em_li[-1] :
                    em_li[-1][a] = np.NaN
                em_li[-1].loc[drug,a] = b.replace('\n', ' ').replace('\r', '')
            else :
                continue
    main_li[-1] = pd.concat([main_li[-1],em_li[-1]],axis=1)

# %%
for df in main_li :
    cols = df.columns
    for i in cols :
        if 'Units' in i :
            df[i] = i.split(':',1)[1].strip()
            df.rename(columns={i:'unit'},inplace=True)
#         if 'Week' in i :
#             df.rename(columns={i:'week'},inplace=True)
#         if 'Change from baseline' in i :
#             df.rename(columns={i:'cfb'},inplace=True)
#         if 'Baseline' in i :
#             df.rename(columns={i:'baseline'},inplace=True)
    df.rename(columns=endpoint_dict,inplace=True)
#     df.reset_index(inplace=True)
    df.dropna(axis=1,how='all',inplace=True)

# %%
final_endpoint = pd.concat(main_li,axis=0)

# %%
final_endpoint.to_excel(f'{eudract_no}final_endpoint.xlsx')
final_endpoint
# Out:
#                                          endpoint_title  \
# arms
# 1     Change From Baseline in Forced Expiratory Volu...
# 2     Change From Baseline in Forced Expiratory Volu...
# 3     Change From Baseline in Forced Expiratory Volu...
# 4     Change From Baseline in Forced Expiratory Volu...
# 5     Change From Baseline in Forced Expiratory Volu...
# 1     Change From Baseline in FEV1 at Week 12 - ITT ...
# 2     Change From Baseline in FEV1 at Week 12 - ITT ...
# 3     Change From Baseline in FEV1 at Week 12 - ITT ...
# 4     Change From Baseline in FEV1 at Week 12 - ITT ...
# 5     Change From Baseline in FEV1 at Week 12 - ITT ...
# 1      Relative Change From Baseline in FEV1 at Week 12
# 2      Relative Change From Baseline in FEV1 at Week 12
# 3      Relative Change From Baseline in FEV1 at Week 12
# 4      Relative Change From Baseline in FEV1 at Week 12
# 5      Relative Change From Baseline in FEV1 at Week 12
# 1     Annualized Event Rate of Loss of Asthma Contro...
# 2     Annualized Event Rate of Loss of Asthma Contro...
# 3     Annualized Event Rate of Loss of Asthma Contro...
# 4     Annualized Event Rate of Loss of Asthma Contro...
# 5     Annualized Event Rate of Loss of Asthma Contro...
# 1     Time to First LOAC Event During the Treatment ...
# 2     Time to First LOAC Event During the Treatment ...
# 3     Time to First LOAC Event During the Treatment ...
# 4     Time to First LOAC Event During the Treatment ...
# 5     Time to First LOAC Event During the Treatment ...
# 1     Annualized Event Rate of Severe Exacerbation D...
# 2     Annualized Event Rate of Severe Exacerbation D...
# 3     Annualized Event Rate of Severe Exacerbation D...
# 4     Annualized Event Rate of Severe Exacerbation D...
# 5     Annualized Event Rate of Severe Exacerbation D...
# 1     Time to First Severe Exacerbation Event During...
# 2     Time to First Severe Exacerbation Event During...
# 3     Time to First Severe Exacerbation Event During...
# 4     Time to First Severe Exacerbation Event During...
# 5     Time to First Severe Exacerbation Event During...
# 1     Change From Baseline in Morning Asthma Symptom...
# 2     Change From Baseline in Morning Asthma Symptom...
# 3     Change From Baseline in Morning Asthma Symptom...
# 4     Change From Baseline in Morning Asthma Symptom...
# 5     Change From Baseline in Morning Asthma Symptom...
# 1     Change From Baseline in Evening Asthma Symptom...
# 2     Change From Baseline in Evening Asthma Symptom...
# 3     Change From Baseline in Evening Asthma Symptom...
# 4     Change From Baseline in Evening Asthma Symptom...
# 5     Change From Baseline in Evening Asthma Symptom...
# 1     Change From Baseline in FEV1 at Week 12 - ITT ...
# 2     Change From Baseline in FEV1 at Week 12 - ITT ...
# 3     Change From Baseline in FEV1 at Week 12 - ITT ...
# 4     Change From Baseline in FEV1 at Week 12 - ITT ...
# 5     Change From Baseline in FEV1 at Week 12 - ITT ...
#
#                                    endpoint_description ednpoint_type  \
# arms
# 1     FEV1 was the volume of air exhaled in the firs...       Primary
# 2     FEV1 was the volume of air exhaled in the firs...       Primary
# 3     FEV1 was the volume of air exhaled in the firs...       Primary
# 4     FEV1 was the volume of air exhaled in the firs...       Primary
# 5     FEV1 was the volume of air exhaled in the firs...       Primary
# 1     Analysis was performed on HEos ITT population ...       Primary
# 2     Analysis was performed on HEos ITT population ...       Primary
# 3     Analysis was performed on HEos ITT population ...       Primary
# 4     Analysis was performed on HEos ITT population ...       Primary
# 5     Analysis was performed on HEos ITT population ...       Primary
# 1     Analysis was performed on ITT population and H...     Secondary
# 2     Analysis was performed on ITT population and H...     Secondary
# 3     Analysis was performed on ITT population and H...     Secondary
# 4     Analysis was performed on ITT population and H...     Secondary
# 5     Analysis was performed on ITT population and H...     Secondary
# 1     LOAC was defined as any of following: ≥6 addit...     Secondary
# 2     LOAC was defined as any of following: ≥6 addit...     Secondary
# 3     LOAC was defined as any of following: ≥6 addit...     Secondary
# 4     LOAC was defined as any of following: ≥6 addit...     Secondary
# 5     LOAC was defined as any of following: ≥6 addit...     Secondary
# 1     The time-to-event variable was defined as the ...     Secondary
# 2     The time-to-event variable was defined as the ...     Secondary
# 3     The time-to-event variable was defined as the ...     Secondary
# 4     The time-to-event variable was defined as the ...     Secondary
# 5     The time-to-event variable was defined as the ...     Secondary
# 1     A severe exacerbation was defined as a deterio...     Secondary
# 2     A severe exacerbation was defined as a deterio...     Secondary
# 3     A severe exacerbation was defined as a deterio...     Secondary
# 4     A severe exacerbation was defined as a deterio...     Secondary
# 5     A severe exacerbation was defined as a deterio...     Secondary
# 1     The time-to-event variable was defined as the ...     Secondary
# 2     The time-to-event variable was defined as the ...     Secondary
# 3     The time-to-event variable was defined as the ...     Secondary
# 4     The time-to-event variable was defined as the ...     Secondary
# 5     The time-to-event variable was defined as the ...     Secondary
# 1     AM (ante meridiem) symptom scoring system rate...     Secondary
# 2     AM (ante meridiem) symptom scoring system rate...     Secondary
# 3     AM (ante meridiem) symptom scoring system rate...     Secondary
# 4     AM (ante meridiem) symptom scoring system rate...     Secondary
# 5     AM (ante meridiem) symptom scoring system rate...     Secondary
# 1     PM (post meridiem) symptom scoring system rate...     Secondary
# 2     PM (post meridiem) symptom scoring system rate...     Secondary
# 3     PM (post meridiem) symptom scoring system rate...     Secondary
# 4     PM (post meridiem) symptom scoring system rate...     Secondary
# 5     PM (post meridiem) symptom scoring system rate...     Secondary
# 1     Analysis was performed on ITT population with ...      Post-hoc
# 2     Analysis was performed on ITT population with ...      Post-hoc
# 3     Analysis was performed on ITT population with ...      Post-hoc
# 4     Analysis was performed on ITT population with ...      Post-hoc
# 5     Analysis was performed on ITT population with ...      Post-hoc
#
#             endpoint_time      End point values n_analyzed  \
# arms
# 1     Baseline to Week 12           Placebo q2w        158
# 2     Baseline to Week 12  Dupilumab 300 mg q2w        157
# 3     Baseline to Week 12  Dupilumab 200 mg q2w        150
# 4     Baseline to Week 12  Dupilumab 300 mg q4w        157
# 5     Baseline to Week 12  Dupilumab 200 mg q4w        154
# 1     Baseline to Week 12           Placebo q2w         68
# 2     Baseline to Week 12  Dupilumab 300 mg q2w         64
# 3     Baseline to Week 12  Dupilumab 200 mg q2w         65
# 4     Baseline to Week 12  Dupilumab 300 mg q4w         66
# 5     Baseline to Week 12  Dupilumab 200 mg q4w         62
# 1     Baseline to Week 12           Placebo q2w        158
# 2     Baseline to Week 12  Dupilumab 300 mg q2w        157
# 3     Baseline to Week 12  Dupilumab 200 mg q2w        150
# 4     Baseline to Week 12  Dupilumab 300 mg q4w        157
# 5     Baseline to Week 12  Dupilumab 200 mg q4w        154
# 1     Baseline to Week 24           Placebo q2w        158
# 2     Baseline to Week 24  Dupilumab 300 mg q2w        156
# 3     Baseline to Week 24  Dupilumab 200 mg q2w        148
# 4     Baseline to Week 24  Dupilumab 300 mg q4w        157
# 5     Baseline to Week 24  Dupilumab 200 mg q4w        150
# 1     Baseline to Week 24           Placebo q2w        158
# 2     Baseline to Week 24  Dupilumab 300 mg q2w        156
# 3     Baseline to Week 24  Dupilumab 200 mg q2w        148
# 4     Baseline to Week 24  Dupilumab 300 mg q4w        157
# 5     Baseline to Week 24  Dupilumab 200 mg q4w        150
# 1     Baseline to Week 24           Placebo q2w        158
# 2     Baseline to Week 24  Dupilumab 300 mg q2w        156
# 3     Baseline to Week 24  Dupilumab 200 mg q2w        148
# 4     Baseline to Week 24  Dupilumab 300 mg q4w        157
# 5     Baseline to Week 24  Dupilumab 200 mg q4w        150
# 1     Baseline to Week 24           Placebo q2w        158
# 2     Baseline to Week 24  Dupilumab 300 mg q2w        156
# 3     Baseline to Week 24  Dupilumab 200 mg q2w        148
# 4     Baseline to Week 24  Dupilumab 300 mg q4w        157
# 5     Baseline to Week 24  Dupilumab 200 mg q4w        150
# 1     Baseline to Week 12           Placebo q2w        158
# 2     Baseline to Week 12  Dupilumab 300 mg q2w        157
# 3     Baseline to Week 12  Dupilumab 200 mg q2w        150
# 4     Baseline to Week 12  Dupilumab 300 mg q4w        157
# 5     Baseline to Week 12  Dupilumab 200 mg q4w        154
# 1       Baseline, Week 12           Placebo q2w        158
# 2       Baseline, Week 12  Dupilumab 300 mg q2w        157
# 3       Baseline, Week 12  Dupilumab 200 mg q2w        150
# 4       Baseline, Week 12  Dupilumab 300 mg q4w        157
# 5       Baseline, Week 12  Dupilumab 200 mg q4w        154
# 1     Baseline to Week 12           Placebo q2w         90
# 2     Baseline to Week 12  Dupilumab 300 mg q2w         93
# 3     Baseline to Week 12  Dupilumab 200 mg q2w         85
# 4     Baseline to Week 12  Dupilumab 300 mg q4w         91
# 5     Baseline to Week 12  Dupilumab 200 mg q4w         92
#
#                                     unit Baseline (n=158,157,150,157,154)  \
# arms
# 1                                  Liter                      1.82 ± 0.55
# 2                                  Liter                      1.85 ± 0.53
# 3                                  Liter                      1.79 ± 0.52
# 4                                  Liter                      1.86 ± 0.57
# 5                                  Liter                      1.88 ± 0.54
# 1                                  Liter                              NaN
# 2                                  Liter                              NaN
# 3                                  Liter                              NaN
# 4                                  Liter                              NaN
# 5                                  Liter                              NaN
# 1                         Percent change                              NaN
# 2                         Percent change                              NaN
# 3                         Percent change                              NaN
# 4                         Percent change                              NaN
# 5                         Percent change                              NaN
# 1                  LOAC per subject-year                              NaN
# 2                  LOAC per subject-year                              NaN
# 3                  LOAC per subject-year                              NaN
# 4                  LOAC per subject-year                              NaN
# 5                  LOAC per subject-year                              NaN
# 1                    Probability of LOAC                              NaN
# 2                    Probability of LOAC                              NaN
# 3                    Probability of LOAC                              NaN
# 4                    Probability of LOAC                              NaN
# 5                    Probability of LOAC                              NaN
# 1          Exacerbation per subject-year                              NaN
# 2          Exacerbation per subject-year                              NaN
# 3          Exacerbation per subject-year                              NaN
# 4          Exacerbation per subject-year                              NaN
# 5          Exacerbation per subject-year                              NaN
# 1     Probability of Severe Exacerbation                              NaN
# 2     Probability of Severe Exacerbation                              NaN
# 3     Probability of Severe Exacerbation                              NaN
# 4     Probability of Severe Exacerbation                              NaN
# 5     Probability of Severe Exacerbation                              NaN
# 1                      Scores on a scale                              NaN
# 2                      Scores on a scale                              NaN
# 3                      Scores on a scale                              NaN
# 4                      Scores on a scale                              NaN
# 5                      Scores on a scale                              NaN
# 1                      Scores on a scale                              NaN
# 2                      Scores on a scale                              NaN
# 3                      Scores on a scale                              NaN
# 4                      Scores on a scale                              NaN
# 5                      Scores on a scale                              NaN
# 1                                  Liter                              NaN
# 2                                  Liter                              NaN
# 3                                  Liter                              NaN
# 4                                  Liter                              NaN
# 5                                  Liter                              NaN
#
#      Week 12 (n=129,146,136,134,134)  \
# arms
# 1                        2.01 ± 0.69
# 2                        2.12 ± 0.59
# 3                        2.12 ± 0.68
# 4                        2.14 ± 0.69
# 5                        2.07 ± 0.63
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
#
#      Change from baseline (n=129,146,136,134,134)  ...  \
# arms                                               ...
# 1                                     0.13 ± 0.37  ...
# 2                                     0.26 ± 0.39  ...
# 3                                     0.32 ± 0.38  ...
# 4                                      0.24 ± 0.4  ...
# 5                                      0.2 ± 0.41  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# 5                                             NaN  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# 5                                             NaN  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# 5                                             NaN  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# 5                                             NaN  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# 5                                             NaN  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# 5                                             NaN  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# 5                                             NaN  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# 5                                             NaN  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# 5                                             NaN  ...
#
#      HEos ITT Population at Week 12 (n=68,64,64,66,59)  \
# arms
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                 0.3 (0.195 to 0.411)
# 2                                0.115 (0.05 to 0.208)
# 3                                0.113 (0.05 to 0.206)
# 4                                0.126 (0.059 to 0.22)
# 5                                0.052 (0.014 to 0.13)
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                0.21 (0.122 to 0.314)
# 2                                0.082 (0.03 to 0.167)
# 3                                0.082 (0.03 to 0.167)
# 4                               0.094 (0.038 to 0.181)
# 5                                0.052 (0.014 to 0.13)
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
#
#      HEos ITT Population at Week 24 (n=68,64,64,66,59)  \
# arms
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                               0.392 (0.275 to 0.507)
# 2                               0.166 (0.085 to 0.269)
# 3                                0.113 (0.05 to 0.206)
# 4                               0.207 (0.117 to 0.314)
# 5                               0.162 (0.079 to 0.269)
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                               0.287 (0.184 to 0.398)
# 2                                0.116 (0.051 to 0.21)
# 3                                0.082 (0.03 to 0.167)
# 4                               0.175 (0.093 to 0.278)
# 5                               0.125 (0.055 to 0.226)
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
#
#      ITT Population at Week 12 (n=158,156,148,157,150)  \
# arms
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                               0.207 (0.147 to 0.274)
# 2                               0.092 (0.053 to 0.145)
# 3                                0.07 (0.036 to 0.119)
# 4                               0.112 (0.068 to 0.168)
# 5                                0.075 (0.04 to 0.125)
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
#
#      ITT Population at Week 24 (n=158,156,148,157,150)  \
# arms
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                               0.266 (0.199 to 0.338)
# 2                               0.112 (0.068 to 0.169)
# 3                               0.091 (0.051 to 0.145)
# 4                               0.195 (0.136 to 0.262)
# 5                                0.16 (0.106 to 0.225)
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
#
#      ITT Population (n=143,148,138,148,140)  \
# arms
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                               -0.23 ± 0.7
# 2                               -0.43 ± 0.7
# 3                              -0.46 ± 0.75
# 4                              -0.52 ± 0.65
# 5                              -0.54 ± 0.64
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
#      HEos ITT Population (n=62,59,58,61,56)  \
# arms
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 1                               -0.29 ± 0.7
# 2                              -0.66 ± 0.67
# 3                              -0.55 ± 0.75
# 4                              -0.57 ± 0.63
# 5                               -0.57 ± 0.6
# 1                              -0.35 ± 0.71
# 2                              -0.84 ± 0.87
# 3                               -0.62 ± 0.7
# 4                              -0.73 ± 0.77
# 5                               -0.69 ± 0.7
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
#      ITT Population (n=143,148,136,148,140) Baseline (n=90,93,85,91,92)  \
# arms
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 1                              -0.27 ± 0.76                         NaN
# 2                              -0.52 ± 0.79                         NaN
# 3                               -0.52 ± 0.8                         NaN
# 4                              -0.59 ± 0.79                         NaN
# 5                              -0.54 ± 0.71                         NaN
# 1                                       NaN                 1.79 ± 0.42
# 2                                       NaN                  1.9 ± 0.55
# 3                                       NaN                 1.79 ± 0.53
# 4                                       NaN                 1.85 ± 0.56
# 5                                       NaN                 1.94 ± 0.56
#
#      Week 12 (n=71,87,79,79,81) Change from Baseline (n=71,87,79,79,81)
# arms
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# 5                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# 5                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# 5                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# 5                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# 5                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# 5                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# 5                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# 5                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# 5                           NaN                                     NaN
# 1                   1.92 ± 0.61                             0.09 ± 0.36
# 2                   2.12 ± 0.63                             0.19 ± 0.31
# 3                   2.02 ± 0.67                             0.23 ± 0.33
# 4                   2.05 ± 0.68                             0.16 ± 0.36
# 5                   2.06 ± 0.68                             0.17 ± 0.36
#
# [50 rows x 44 columns]
